# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px"><h1>Pandas</h1>
# <code>By AKSHAY KASHYAP</code></div>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# <hr><div class="alert alert-block alert-danger" style="margin-top: 20px">
#     <h2>Read data and work on it</h2></div><hr>

# %%
data = pd.read_csv("pandas_data/gapminder.tsv", sep="\t") # reading data

# %%
data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
data.head() # only 5 by default (top)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data.head(10) # here we specify , we want 10 (top)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
data.tail() # only 5 by default (bottom)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
data.tail(3) # here we specify , we want 3 (bottom)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %% [markdown]
# <hr><div class="alert alert-block alert-danger" style="margin-top: 20px">
# from pandas import * <br>
# don't do this <br>
# (beacuse funtion may collide, and u can't understand from which library it is coming from) </div>
# <hr>

# %%
data.shape #row,column
# Out:
# (1704, 6)

# %%
data.size #row*column
# Out:
# 10224

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
data.info
# Out:
# <bound method DataFrame.info of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
data.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <hr><div class="alert alert-block alert-danger" style="margin-top: 20px">
#     <h3>data[ ] v/s data[[ ]]</h3>
#     <hr>data['country'] v/s data[['country']]
# </div><hr>

# %%
country = data['country'] # return series (1D)
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
con = data['country','continent'] #it will not work
con
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Envs\datascience\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'continent')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ...

# %%
country  = data[['country']] # return DataFrame 
country

# %%
con = data[['country','continent']] # also select multiple column
con
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %% [markdown]
# <hr><div class="alert alert-block alert-danger" style="margin-top: 20px">
# <h3>loc[ ] & iloc[ ]</h3></div><hr>

# %% [markdown]
# * loc[]: Used for label-based indexing to access a group of rows and columns<br>
# by labels or a boolean array.
# * iloc[]: Used for integer-based (position-based) indexing to access rows and columns<br>
# by their integer positions.

# %%
data.loc[2]
# Out:
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap      853.10071
# Name: 2, dtype: object

# %%
data.loc[[0,3,7,9]]  # must double [[]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
#df.iloc[start_row : end _row , start_col: end_col ] we can select particular rorws and colums

subset = data.loc[ : , ['year', 'pop']]  # [only year,pop column]

#subset = data.loc[ : , 'year': 'pop']  # year to pop

# %%
subset.head()
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
data.iloc[-1]  #data.loc[-1] doesn't work
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
data.iloc[[0,-1,3,-7,9]] # must double [[]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 1697     Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 9     Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
#df.iloc[start_row : end _row , start_col: end_col ]  we can select particular rorws and colums
subset = data.iloc[:, [2, 4]]  #2 & 4 only
#subset = data.iloc[:, 2: 4] #  2 to 4

# %%
subset.tail()
# Out:
#       year       pop
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143

# %%
# selecting row from column on condition
data.loc[data['country']== "India"]
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
#using with more and one condition
data.loc[(data["country"]== "India") & (data["year"] == 1982)]
# Out:
#     country continent  year  lifeExp        pop   gdpPercap
# 702   India      Asia  1982   56.596  708000000  855.723538

# %% [markdown]
# <hr><div class="alert alert-block alert-danger" style="margin-top: 20px">
# <h3>GroupBy</h3></div><hr>

# %%
data.groupby(data["country"])

# %%
data.groupby(data["country"])["lifeExp"].mean()
# Out:
# country
# Afghanistan           37.478833
# Albania               68.432917
# Algeria               59.030167
# Angola                37.883500
# Argentina             69.060417
#                         ...
# Vietnam               57.479500
# West Bank and Gaza    60.328667
# Yemen, Rep.           46.780417
# Zambia                45.996333
# Zimbabwe              52.663167
# Name: lifeExp, Length: 142, dtype: float64

# %% [markdown]
# <hr><h3>Importing numpy just to do mean, std(Standard Deviation)</h3><hr>

# %%
import numpy as np
data.groupby(["country","year"])["lifeExp"].agg('std') #old .agg(np.std)
# groupby on the basis of country and year , and show lifeExp
# Out:
# country      year
# Afghanistan  1952   NaN
#              1957   NaN
#              1962   NaN
#              1967   NaN
#              1972   NaN
#                      ..
# Zimbabwe     1987   NaN
#              1992   NaN
#              1997   NaN
#              2002   NaN
#              2007   NaN
# Name: lifeExp, Length: 1704, dtype: float64

# %%
data.groupby(["country","year"])["lifeExp"].agg("std").reset_index() #reset index
# Out:
#           country  year  lifeExp
# 0     Afghanistan  1952      NaN
# 1     Afghanistan  1957      NaN
# 2     Afghanistan  1962      NaN
# 3     Afghanistan  1967      NaN
# 4     Afghanistan  1972      NaN
# ...           ...   ...      ...
# 1699     Zimbabwe  1987      NaN
# 1700     Zimbabwe  1992      NaN
# 1701     Zimbabwe  1997      NaN
# 1702     Zimbabwe  2002      NaN
# 1703     Zimbabwe  2007      NaN
#
# [1704 rows x 3 columns]

# %%
data.groupby(["year"])["lifeExp"].agg("std")
# Out:
# year
# 1952    12.225956
# 1957    12.231286
# 1962    12.097245
# 1967    11.718858
# 1972    11.381953
# 1977    11.227229
# 1982    10.770618
# 1987    10.556285
# 1992    11.227380
# 1997    11.559439
# 2002    12.279823
# 2007    12.073021
# Name: lifeExp, dtype: float64

# %%
data.groupby(["year", "continent"])[["lifeExp","gdpPercap"]].agg("mean") #.reser_inde() #if you wanna reset index
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...
